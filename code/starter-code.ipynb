# %% [markdown]
# # Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1: Introduction
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# At the start of the pandemic, the University of California decided to temporarily put the use of standardized testing in their admissions process on hold.
#
# To put it mildly, this has been a contentious <a href="https://www.wsj.com/articles/california-defines-testing-down-11589746251">issue</a>.
#
# On one hand, many are asking, without standardized testing, how can we know the best students are being admitted?
#
# One the other hand, some are arguing that we never knew that in the first place, because standardized testing has always been unfair and isn't an accurate assessment of a student's ability or potential.
#
# With that in mind, the University of California has tasked me with the job of determining the following:
#
# Is standardized testing an equitable measure for student performance?

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# Still,

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def calculate_mean(numbers):
    sum_num = 0
    
    for value in numbers:
        sum_num += value
        
    mean = sum_num/len(numbers)
    
    return mean

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def calculate_std(numbers):
    sum_num = 0
    
    for value in numbers:
        sum_num += value
        
    mean = sum_num/len(numbers)
    
    diff_sum = 0
    
    for number in numbers:
        diff_sum += (number - mean)**2
    
    return (diff_sum/len(numbers))**0.5

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def data_clean(value):
    if value == '—':
        cleaned_value = np.nan
    
    else:
        cleaned_value = (float(value.replace("%", "")))/100
    
    return cleaned_value

# %% [markdown]
# Additional functions

# %%
def dollar_converter(dollar_amount):
    if dollar_amount == '—':
        new_value = np.nan
    
    else:
        new_value = int(dollar_amount.replace("$","").replace(',', ''))
    return round((new_value), 2)

# %%
def to_float_converter(num):
    if num == '—':
        to_float = np.nan
    
    elif num == '*':
        to_float = np.nan
    
    else:
        to_float = float(num)
    
    return to_float

# %%
def data_clean_no_replace(value):
    if value == '—':
        new_value = np.nan
        
    elif value == '*':
        new_value = np.nan
    
    else:
        new_value = (float(value)/100)
    
    return new_value

# %% [markdown]
# ---
# # Part 2: EDA
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import missingno as msno
# %matplotlib inline

# %matplotlib inline

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))#to expand the size of my container so it can take fill up my entire monitor

plt.style.use('fivethirtyeight')
# %config InlineBackend.figure_format = 'retina'

pd.options.display.max_rows = 200 #increasing maximum viewable rows and columns
pd.options.display.max_columns = 200
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
act_19_ca = pd.read_csv('../data/act_2019_ca.csv').drop(columns='Unnamed: 17')
act_20_ca = pd.read_csv('../data/act_2020_ca.csv')
sat_19_ca = pd.read_csv('../data/sat_2019_ca.csv').drop(columns='Unnamed: 25')
sat_20_ca = pd.read_csv('../data/sat_2020_ca.csv')
school_district_equity = pd.read_csv('../data/school_districts_equity_ca.csv').drop(columns='Unnamed: 0')
district_enrollment_by_ethnicity = pd.read_csv('../data/district_enrollment_by_ethnicity_ca_21.csv')

# %% [markdown]
# # Display the data

# %%
act_19_ca.head()
# Out:
#             CDS  CCode     CDCode      SCode RType  \
# 0  3.366993e+13   33.0  3366993.0   129882.0     S
# 1  1.964212e+13   19.0  1964212.0  1995596.0     S
# 2  1.563776e+13   15.0  1563776.0  1530377.0     S
# 3  4.369666e+13   43.0  4369666.0  4333795.0     S
# 4  1.964733e+13   19.0  1964733.0  1935121.0     S
#
#                              SName                  DName        CName  \
# 0  21st Century Learning Institute       Beaumont Unified    Riverside
# 1      ABC Secondary (Alternative)            ABC Unified  Los Angeles
# 2      Abraham Lincoln Alternative  Southern Kern Unified         Kern
# 3             Abraham Lincoln High       San Jose Unified  Santa Clara
# 4      Abraham Lincoln Senior High    Los Angeles Unified  Los Angeles
#
#    Enroll12  NumTstTakr AvgScrRead AvgScrEng AvgScrMath AvgScrSci NumGE21  \
# 0      18.0         0.0        NaN       NaN        NaN       NaN     NaN
# 1      58.0         0.0        NaN       NaN        NaN       NaN     NaN
# ...

# %%
act_20_ca.head()
# Out:
#              CDS RType                                     SName  \
# 0  1100170112607     S    Envision Academy for Arts & Technology
# 1  1316170131763     S    California School for the Deaf-Fremont
# 2  1611190106401     S  Alameda Science and Technology Institute
# 3  1611190119222     S             Nea Community Learning Center
# 4  1611190130229     S                              Alameda High
#
#                                                DName    CName  Enroll12  \
# 0                 Alameda County Office of Education  Alameda        85
# 1  California School for the Deaf-Fremont (State ...  Alameda        85
# 2                                    Alameda Unified  Alameda        49
# 3                                    Alameda Unified  Alameda        34
# 4                                    Alameda Unified  Alameda       462
#
#    NumTstTakr AvgScrEng AvgScrRead AvgScrMath AvgScrSci NumGE21 PctGE21  \
# ...

# %%
sat_19_ca.head()
# Out:
#             CDS  CCode     CDCode      SCode RType                    SName  \
# 0  6.615981e+12    6.0   661598.0   630046.0     S  Colusa Alternative Home
# 1  6.616061e+12    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4  1.964733e+13   19.0  1964733.0  1931856.0     S     Whitman Continuation
#
#                  DName        CName  Enroll12  NumTSTTakr12 NumERWBenchmark12  \
# 0       Colusa Unified       Colusa      18.0           0.0               NaN
# 1      Maxwell Unified       Colusa      29.0          10.0                 *
# 2  Los Angeles Unified  Los Angeles     206.0         102.0                31
# 3  Los Angeles Unified  Los Angeles     227.0         113.0                54
# 4  Los Angeles Unified  Los Angeles      18.0          14.0                 *
#
# ...

# %%
sat_20_ca.head()
# Out:
#               CDS  CCode   CDCode    SCode RType                      SName  \
# 0  19647251930411     19  1964725  1930411     S                Avalon K-12
# 1  30103060133959     30  3010306   133959     S  Unity Middle College High
# 2  33672073335973     33  3367207  3335973     S                Perris High
# 3  33672153334406     33  3367215  3334406     S         John W. North High
# 4  39686270129916     39  3968627   129916     S   Valley View Charter Prep
#
#                                    DName        CName  Enroll12  NumTSTTakr12  \
# 0                     Long Beach Unified  Los Angeles        39            18
# 1  Orange County Department of Education       Orange        24             5
# 2                      Perris Union High    Riverside       431           122
# 3                      Riverside Unified    Riverside       519           202
# 4               New Jerusalem Elementary  San Joaquin        23             6
#
# ...

# %%
school_district_equity.head()
# Out:
#             school_district  score  \
# 0               Abc Unified   8.12
# 1       Acalanes Union High  77.56
# 2  Acton-Agua Dulce Unified  32.54
# 3       Adelanto Elementary  30.62
# 4           Alameda Unified  32.25
#
#   expenditures_for_public_elementary_and_secondary_schools_per_pupil  \
# 0                                            $12,189
# 1                                            $15,267
# 2                                            $14,318
# 3                                            $12,993
# 4                                            $13,436
#
#   income_by_school_district
# 0                   $81,101
# 1                  $129,146
# 2                  $100,556
# 3                   $60,414
# 4                  $104,756

# %%
district_enrollment_by_ethnicity.head()
# Out:
#                                                 name total_students  \
# 0                 Alameda County Office of Education          3,960
# 1                                    Alameda Unified         10,927
# 2                                Albany City Unified          3,501
# 3                                   Berkeley Unified          9,409
# 4  California School for the Blind (State Special...             58
#
#   african_american american_indian_or_alaska_native   asian filipino  \
# 0           17.10%                            0.40%  12.20%    1.30%
# 1            6.50%                            0.30%  25.30%    5.50%
# 2            3.40%                            0.20%  28.80%    1.10%
# 3           12.70%                            0.30%   8.30%    0.80%
# 4           13.80%                            0.00%  12.10%    1.70%
#
#   hispanic_or_latino pacific_islander   white two _or_more_races not_reported
# ...

# %% [markdown]
# # Checking for missing nulls

# %%
act_19_ca.isnull().sum()
# Out:
# CDS             1
# CCode           1
# CDCode          1
# SCode         523
# RType           1
# SName         581
# DName          59
# CName           1
# Enroll12        1
# NumTstTakr      1
# AvgScrRead    357
# AvgScrEng     357
# AvgScrMath    357
# AvgScrSci     357
# NumGE21       357
# PctGE21       357
# Year            1
# dtype: int64

# %%
act_20_ca.isnull().sum()
# Out:
# CDS             0
# RType           0
# SName         580
# DName          58
# CName           1
# Enroll12        0
# NumTstTakr      0
# AvgScrEng     449
# AvgScrRead    449
# AvgScrMath    449
# AvgScrSci     449
# NumGE21       449
# PctGE21       449
# Year            0
# dtype: int64

# %%
sat_19_ca.isnull().sum()
# Out:
# CDS                        1
# CCode                      1
# CDCode                     1
# SCode                      1
# RType                      1
# SName                    598
# DName                     59
# CName                      1
# Enroll12                   1
# NumTSTTakr12               1
# NumERWBenchmark12        276
# PctERWBenchmark12        276
# NumMathBenchmark12       276
# PctMathBenchmark12       276
# Enroll11                   1
# NumTSTTakr11               1
# NumERWBenchmark11        311
# PctERWBenchmark11        311
# NumMathBenchmark11       311
# PctMathBenchmark11       311
# TotNumBothBenchmark12    276
# PctBothBenchmark12       276
# TotNumBothBenchmark11    311
# PctBothBenchmark11       311
# Year                       1
# dtype: int64

# %%
sat_20_ca.isnull().sum()
# Out:
# CDS                        0
# CCode                      0
# CDCode                     0
# SCode                      0
# RType                      0
# SName                    590
# DName                     58
# CName                      1
# Enroll12                   0
# NumTSTTakr12               0
# NumERWBenchmark12        236
# PctERWBenchmark12        236
# NumMathBenchmark12       236
# PctMathBenchmark12       236
# Enroll11                   0
# NumTSTTakr11               0
# NumERWBenchmark11        713
# PctERWBenchmark11        713
# NumMathBenchmark11       713
# PctMathBenchmark11       713
# TotNumBothBenchmark12    236
# PctBothBenchmark12       236
# TotNumBothBenchmark11    713
# PctBothBenchmark11       713
# Year                       0
# dtype: int64

# %%
school_district_equity.isnull().sum()
# Out:
# school_district                                                       0
# score                                                                 0
# expenditures_for_public_elementary_and_secondary_schools_per_pupil    0
# income_by_school_district                                             0
# dtype: int64

# %%
district_enrollment_by_ethnicity.isnull().sum()
# Out:
# name                                0
# total_students                      0
# african_american                    0
# american_indian_or_alaska_native    0
# asian                               0
# filipino                            0
# hispanic_or_latino                  0
# pacific_islander                    0
# white                               0
# two _or_more_races                  0
# not_reported                        0
# dtype: int64

# %% [markdown]
# # Checking for obvious issues with the observations

# %% [markdown]
# In order to check for obvious issues, I had to first fix incorrect data types in several instances.

# %%
act_19_ca.dtypes
# Out:
# CDS           float64
# CCode         float64
# CDCode        float64
# SCode         float64
# RType          object
# SName          object
# DName          object
# CName          object
# Enroll12      float64
# NumTstTakr    float64
# AvgScrRead     object
# AvgScrEng      object
# AvgScrMath     object
# AvgScrSci      object
# NumGE21        object
# PctGE21        object
# Year           object
# dtype: object

# %%
act_19_ca['AvgScrRead']= act_19_ca['AvgScrRead'].apply(to_float_converter)
act_19_ca['AvgScrEng']= act_19_ca['AvgScrEng'].apply(to_float_converter)
act_19_ca['AvgScrMath']= act_19_ca['AvgScrMath'].apply(to_float_converter)
act_19_ca['AvgScrSci']= act_19_ca['AvgScrSci'].apply(to_float_converter)
act_19_ca['NumGE21']= act_19_ca['NumGE21'].apply(to_float_converter)
act_19_ca['PctGE21']= act_19_ca['PctGE21'].apply(to_float_converter)

# %%
act_19_ca.describe()
# Out:
#                 CDS        CCode        CDCode         SCode       Enroll12  \
# count  2.309000e+03  2309.000000  2.309000e+03  1.787000e+03    2309.000000
# mean   2.929718e+13    28.666522  2.855616e+06  1.902681e+06     828.172802
# std    1.444996e+13    14.425498  1.492574e+06  1.838954e+06   10667.048988
# min    0.000000e+00     0.000000  0.000000e+00  0.000000e+00       0.000000
# 25%    1.964725e+13    19.000000  1.964519e+06  1.254385e+05      78.000000
# 50%    3.066647e+13    30.000000  3.066548e+06  1.930288e+06     218.000000
# 75%    3.868478e+13    38.000000  3.777032e+06  3.435674e+06     497.000000
# max    5.872770e+13    58.000000  5.872769e+06  6.120893e+06  489650.000000
#
#          NumTstTakr   AvgScrRead    AvgScrEng   AvgScrMath    AvgScrSci  \
# count   2309.000000  1421.000000  1421.000000  1421.000000  1421.000000
# mean     143.182763    22.075299    21.204082    21.416608    21.356791
# ...

# %%
act_20_ca.dtypes
# Out:
# CDS            int64
# RType         object
# SName         object
# DName         object
# CName         object
# Enroll12       int64
# NumTstTakr     int64
# AvgScrEng     object
# AvgScrRead    object
# AvgScrMath    object
# AvgScrSci     object
# NumGE21       object
# PctGE21       object
# Year          object
# dtype: object

# %%
act_20_ca['AvgScrRead']= act_20_ca['AvgScrRead'].apply(to_float_converter)
act_20_ca['AvgScrEng']= act_20_ca['AvgScrEng'].apply(to_float_converter)
act_20_ca['AvgScrMath']= act_20_ca['AvgScrMath'].apply(to_float_converter)
act_20_ca['AvgScrSci']= act_20_ca['AvgScrSci'].apply(to_float_converter)
act_20_ca['NumGE21']= act_20_ca['NumGE21'].apply(to_float_converter)
act_20_ca['PctGE21']= act_20_ca['PctGE21'].apply(to_float_converter)

# %%
act_20_ca.describe()
# Out:
#                 CDS       Enroll12    NumTstTakr    AvgScrEng   AvgScrRead  \
# count  2.304000e+03    2304.000000   2304.000000  1274.000000  1274.000000
# mean   2.935290e+13     824.096354    113.390625    21.724490    22.746468
# std    1.440764e+13   10601.866901   1431.769788     4.080908     3.702307
# min    0.000000e+00       0.000000      0.000000    10.000000    12.000000
# 25%    1.964725e+13      77.000000      1.750000    18.000000    20.000000
# 50%    3.066647e+13     221.000000     21.000000    22.000000    23.000000
# 75%    3.868478e+13     482.250000     69.000000    25.000000    26.000000
# max    5.872770e+13  486592.000000  65332.000000    33.000000    32.000000
#
#         AvgScrMath    AvgScrSci       NumGE21      PctGE21
# count  1274.000000  1274.000000   1274.000000  1274.000000
# mean     21.915228    21.870487    121.002355    56.703179
# std       3.472804     3.286243   1139.840474    25.696094
# ...

# %%
sat_19_ca.dtypes
# Out:
# CDS                      float64
# CCode                    float64
# CDCode                   float64
# SCode                    float64
# RType                     object
# SName                     object
# DName                     object
# CName                     object
# Enroll12                 float64
# NumTSTTakr12             float64
# NumERWBenchmark12         object
# PctERWBenchmark12         object
# NumMathBenchmark12        object
# PctMathBenchmark12        object
# Enroll11                 float64
# NumTSTTakr11             float64
# NumERWBenchmark11         object
# PctERWBenchmark11         object
# NumMathBenchmark11        object
# PctMathBenchmark11        object
# TotNumBothBenchmark12     object
# PctBothBenchmark12        object
# TotNumBothBenchmark11     object
# PctBothBenchmark11        object
# Year                      object
# dtype: object

# %%
sat_19_ca['NumERWBenchmark12'] = sat_19_ca['NumERWBenchmark12'].apply(data_clean_no_replace)
sat_19_ca['PctERWBenchmark12'] = sat_19_ca['PctERWBenchmark12'].apply(data_clean_no_replace)
sat_19_ca['NumMathBenchmark12'] = sat_19_ca['NumMathBenchmark12'].apply(data_clean_no_replace)
sat_19_ca['PctMathBenchmark12'] = sat_19_ca['PctMathBenchmark12'].apply(data_clean_no_replace)
sat_19_ca['NumERWBenchmark11'] = sat_19_ca['NumERWBenchmark11'].apply(data_clean_no_replace)
sat_19_ca['PctERWBenchmark11'] = sat_19_ca['PctERWBenchmark11'].apply(data_clean_no_replace)
sat_19_ca['NumMathBenchmark11'] = sat_19_ca['NumMathBenchmark11'].apply(data_clean_no_replace)
sat_19_ca['PctMathBenchmark11'] = sat_19_ca['PctMathBenchmark11'].apply(data_clean_no_replace)
sat_19_ca['TotNumBothBenchmark12'] = sat_19_ca['TotNumBothBenchmark12'].apply(data_clean_no_replace)
sat_19_ca['PctBothBenchmark12'] = sat_19_ca['PctBothBenchmark12'].apply(data_clean_no_replace)
sat_19_ca['TotNumBothBenchmark11'] = sat_19_ca['TotNumBothBenchmark11'].apply(data_clean_no_replace)
sat_19_ca['PctBothBenchmark11'] = sat_19_ca['PctBothBenchmark11'].apply(data_clean_no_replace)

# %%
sat_19_ca.describe()
# Out:
#                 CDS        CCode        CDCode         SCode       Enroll12  \
# count  2.579000e+03  2579.000000  2.579000e+03  2.579000e+03    2579.000000
# mean   2.915139e+13    28.519581  2.915138e+06  1.544913e+06     748.155487
# std    1.428328e+13    14.258173  1.428327e+06  1.812049e+06   10095.758681
# min    0.000000e+00     0.000000  0.000000e+00  0.000000e+00       0.000000
# 25%    1.964725e+13    19.000000  1.964725e+06  1.025080e+05      63.000000
# 50%    3.066597e+13    30.000000  3.066597e+06  1.377860e+05     171.000000
# 75%    3.777103e+13    37.000000  3.777103e+06  3.037422e+06     462.000000
# max    5.872770e+13    58.000000  5.872769e+06  6.120893e+06  489650.000000
#
#         NumTSTTakr12  NumERWBenchmark12  PctERWBenchmark12  \
# count    2579.000000        1722.000000        1722.000000
# mean      264.274137           2.695401           0.683184
# std      3568.205236          29.569483           0.203293
# ...

# %%
sat_20_ca.dtypes
# Out:
# CDS                       int64
# CCode                     int64
# CDCode                    int64
# SCode                     int64
# RType                    object
# SName                    object
# DName                    object
# CName                    object
# Enroll12                  int64
# NumTSTTakr12              int64
# NumERWBenchmark12        object
# PctERWBenchmark12        object
# NumMathBenchmark12       object
# PctMathBenchmark12       object
# Enroll11                  int64
# NumTSTTakr11              int64
# NumERWBenchmark11        object
# PctERWBenchmark11        object
# NumMathBenchmark11       object
# PctMathBenchmark11       object
# TotNumBothBenchmark12    object
# PctBothBenchmark12       object
# TotNumBothBenchmark11    object
# PctBothBenchmark11       object
# Year                     object
# dtype: object

# %%
sat_20_ca['NumERWBenchmark12'] = sat_20_ca['NumERWBenchmark12'].apply(data_clean_no_replace)
sat_20_ca['PctERWBenchmark12'] = sat_20_ca['PctERWBenchmark12'].apply(data_clean_no_replace)
sat_20_ca['NumMathBenchmark12'] = sat_20_ca['NumMathBenchmark12'].apply(data_clean_no_replace)
sat_20_ca['PctMathBenchmark12'] = sat_20_ca['PctMathBenchmark12'].apply(data_clean_no_replace)
sat_20_ca['NumERWBenchmark11'] = sat_20_ca['NumERWBenchmark11'].apply(data_clean_no_replace)
sat_20_ca['PctERWBenchmark11'] = sat_20_ca['PctERWBenchmark11'].apply(data_clean_no_replace)
sat_20_ca['NumMathBenchmark11'] = sat_20_ca['NumMathBenchmark11'].apply(data_clean_no_replace)
sat_20_ca['PctMathBenchmark11'] = sat_20_ca['PctMathBenchmark11'].apply(data_clean_no_replace)
sat_20_ca['TotNumBothBenchmark12'] = sat_20_ca['TotNumBothBenchmark12'].apply(data_clean_no_replace)
sat_20_ca['PctBothBenchmark12'] = sat_20_ca['PctBothBenchmark12'].apply(data_clean_no_replace)
sat_20_ca['TotNumBothBenchmark11'] = sat_20_ca['TotNumBothBenchmark11'].apply(data_clean_no_replace)
sat_20_ca['PctBothBenchmark11'] = sat_20_ca['PctBothBenchmark11'].apply(data_clean_no_replace)

# %%
sat_20_ca.describe()
# Out:
#                 CDS        CCode        CDCode         SCode       Enroll12  \
# count  2.482000e+03  2482.000000  2.482000e+03  2.482000e+03    2482.000000
# mean   2.924281e+13    28.612006  2.924281e+06  1.499517e+06     769.614424
# std    1.427667e+13    14.251998  1.427667e+06  1.799503e+06   10216.378983
# min    0.000000e+00     0.000000  0.000000e+00  0.000000e+00       0.000000
# 25%    1.964733e+13    19.000000  1.964733e+06  1.019312e+05      68.000000
# 50%    3.066647e+13    30.000000  3.066647e+06  1.370625e+05     188.000000
# 75%    3.794277e+13    37.750000  3.794277e+06  3.035332e+06     466.500000
# max    5.872770e+13    58.000000  5.872769e+06  6.120893e+06  486592.000000
#
#         NumTSTTakr12  NumERWBenchmark12  PctERWBenchmark12  \
# count    2482.000000        1701.000000        1701.000000
# mean      261.054795           2.552957           0.678733
# std      3449.344838          27.840026           0.204244
# ...

# %%
school_district_equity.dtypes
# Out:
# school_district                                                        object
# score                                                                 float64
# expenditures_for_public_elementary_and_secondary_schools_per_pupil     object
# income_by_school_district                                              object
# dtype: object

# %%
school_district_equity['income_by_school_district']= school_district_equity['income_by_school_district'].apply(dollar_converter)
school_district_equity['expenditures_for_public_elementary_and_secondary_schools_per_pupil']= school_district_equity['expenditures_for_public_elementary_and_secondary_schools_per_pupil'].apply(dollar_converter)

# %%
district_enrollment_by_ethnicity.head()
# Out:
#                                                 name total_students  \
# 0                 Alameda County Office of Education          3,960
# 1                                    Alameda Unified         10,927
# 2                                Albany City Unified          3,501
# 3                                   Berkeley Unified          9,409
# 4  California School for the Blind (State Special...             58
#
#   african_american american_indian_or_alaska_native   asian filipino  \
# 0           17.10%                            0.40%  12.20%    1.30%
# 1            6.50%                            0.30%  25.30%    5.50%
# 2            3.40%                            0.20%  28.80%    1.10%
# 3           12.70%                            0.30%   8.30%    0.80%
# 4           13.80%                            0.00%  12.10%    1.70%
#
#   hispanic_or_latino pacific_islander   white two _or_more_races not_reported
# ...

# %%
district_enrollment_by_ethnicity.dtypes
# Out:
# name                                object
# total_students                      object
# african_american                    object
# american_indian_or_alaska_native    object
# asian                               object
# filipino                            object
# hispanic_or_latino                  object
# pacific_islander                    object
# white                               object
# two _or_more_races                  object
# not_reported                        object
# dtype: object

# %%
district_enrollment_by_ethnicity.drop('total_students', axis=1, inplace=True)
district_enrollment_by_ethnicity['african_american'] = district_enrollment_by_ethnicity['african_american'].apply(data_clean)
district_enrollment_by_ethnicity['american_indian_or_alaska_native'] = district_enrollment_by_ethnicity['american_indian_or_alaska_native'].apply(data_clean)
district_enrollment_by_ethnicity['asian'] = district_enrollment_by_ethnicity['asian'].apply(data_clean)
district_enrollment_by_ethnicity['filipino'] = district_enrollment_by_ethnicity['filipino'].apply(data_clean)
district_enrollment_by_ethnicity['hispanic_or_latino'] = district_enrollment_by_ethnicity['hispanic_or_latino'].apply(data_clean)
district_enrollment_by_ethnicity['pacific_islander'] = district_enrollment_by_ethnicity['pacific_islander'].apply(data_clean)
district_enrollment_by_ethnicity['white'] = district_enrollment_by_ethnicity['white'].apply(data_clean)
district_enrollment_by_ethnicity['two _or_more_races'] = district_enrollment_by_ethnicity['two _or_more_races'].apply(data_clean)
district_enrollment_by_ethnicity['not_reported'] = district_enrollment_by_ethnicity['not_reported'].apply(data_clean)

# %%
district_enrollment_by_ethnicity.describe()
# Out:
#        african_american  american_indian_or_alaska_native        asian  \
# count       1029.000000                       1029.000000  1029.000000
# mean           0.027558                          0.017983     0.053627
# std            0.050156                          0.065269     0.100193
# min            0.000000                          0.000000     0.000000
# 25%            0.004000                          0.001000     0.005000
# 50%            0.011000                          0.004000     0.015000
# 75%            0.029000                          0.010000     0.051000
# max            0.626000                          1.000000     0.724000
#
#           filipino  hispanic_or_latino  pacific_islander        white  \
# count  1029.000000         1029.000000       1029.000000  1029.000000
# mean      0.012960            0.466338          0.003605     0.358362
# std       0.024595            0.279329          0.017396     0.251743
# ...

# %% [markdown]
# # Display the data types of each feature

# %%
act_19_ca.dtypes
# Out:
# CDS           float64
# CCode         float64
# CDCode        float64
# SCode         float64
# RType          object
# SName          object
# DName          object
# CName          object
# Enroll12      float64
# NumTstTakr    float64
# AvgScrRead    float64
# AvgScrEng     float64
# AvgScrMath    float64
# AvgScrSci     float64
# NumGE21       float64
# PctGE21       float64
# Year           object
# dtype: object

# %% [markdown]
# Converting PctGE21 to percentage.

# %%
act_19_ca['PctGE21'] = (act_19_ca['PctGE21']/100).round(2)

# %%
act_20_ca.dtypes
# Out:
# CDS             int64
# RType          object
# SName          object
# DName          object
# CName          object
# Enroll12        int64
# NumTstTakr      int64
# AvgScrEng     float64
# AvgScrRead    float64
# AvgScrMath    float64
# AvgScrSci     float64
# NumGE21       float64
# PctGE21       float64
# Year           object
# dtype: object

# %%
#convert PctGE21 to percent
act_20_ca['PctGE21'] = (act_20_ca['PctGE21']/100).round(2)

# %%
sat_19_ca.dtypes
# Out:
# CDS                      float64
# CCode                    float64
# CDCode                   float64
# SCode                    float64
# RType                     object
# SName                     object
# DName                     object
# CName                     object
# Enroll12                 float64
# NumTSTTakr12             float64
# NumERWBenchmark12        float64
# PctERWBenchmark12        float64
# NumMathBenchmark12       float64
# PctMathBenchmark12       float64
# Enroll11                 float64
# NumTSTTakr11             float64
# NumERWBenchmark11        float64
# PctERWBenchmark11        float64
# NumMathBenchmark11       float64
# PctMathBenchmark11       float64
# TotNumBothBenchmark12    float64
# PctBothBenchmark12       float64
# TotNumBothBenchmark11    float64
# PctBothBenchmark11       float64
# Year                      object
# dtype: object

# %%
sat_20_ca.dtypes
# Out:
# CDS                        int64
# CCode                      int64
# CDCode                     int64
# SCode                      int64
# RType                     object
# SName                     object
# DName                     object
# CName                     object
# Enroll12                   int64
# NumTSTTakr12               int64
# NumERWBenchmark12        float64
# PctERWBenchmark12        float64
# NumMathBenchmark12       float64
# PctMathBenchmark12       float64
# Enroll11                   int64
# NumTSTTakr11               int64
# NumERWBenchmark11        float64
# PctERWBenchmark11        float64
# NumMathBenchmark11       float64
# PctMathBenchmark11       float64
# TotNumBothBenchmark12    float64
# PctBothBenchmark12       float64
# TotNumBothBenchmark11    float64
# PctBothBenchmark11       float64
# Year                      object
# dtype: object

# %%
school_district_equity.dtypes
# Out:
# school_district                                                        object
# score                                                                 float64
# expenditures_for_public_elementary_and_secondary_schools_per_pupil      int64
# income_by_school_district                                               int64
# dtype: object

# %%
district_enrollment_by_ethnicity.dtypes
# Out:
# name                                 object
# african_american                    float64
# american_indian_or_alaska_native    float64
# asian                               float64
# filipino                            float64
# hispanic_or_latino                  float64
# pacific_islander                    float64
# white                               float64
# two _or_more_races                  float64
# not_reported                        float64
# dtype: object

# %% [markdown]
# # Giving columns more descriptive names

# %%
act_19_ca_columns_dict ={'RType' : 'record_type', 'DName' : 'district', 'Enroll12' : 'students_in_grade_12_19', 'NumTstTakr' : 'act_test_takers_19', 
              'AvgScrRead' : 'act_read_19', 'AvgScrEng' : 'act_eng_19', 'AvgScrMath' : 'act_math_19', 
              'AvgScrSci' : 'act_sci_19', 'PctGE21' : 'act_comp_over_21_19', 'Year' : 'year'}

act_19_ca.rename(columns = act_19_ca_columns_dict, inplace=True)

act_19_ca.head(1)
# Out:
#             CDS  CCode     CDCode     SCode record_type  \
# 0  3.366993e+13   33.0  3366993.0  129882.0           S
#
#                              SName          district      CName  \
# 0  21st Century Learning Institute  Beaumont Unified  Riverside
#
#    students_in_grade_12_19  act_test_takers_19  act_read_19  act_eng_19  \
# 0                     18.0                 0.0          NaN         NaN
#
#    act_math_19  act_sci_19  NumGE21  act_comp_over_21_19     year
# 0          NaN         NaN      NaN                  NaN  2018-19

# %%
act_20_ca_columns_dict ={'RType' : 'record_type', 'DName' : 'district', 'Enroll12' : 'students_in_grade_12_20', 'NumTstTakr' : 'act_test_takers_20', 
              'AvgScrRead' : 'act_read_20', 'AvgScrEng' : 'act_eng_20', 'AvgScrMath' : 'act_math_20', 
              'AvgScrSci' : 'act_sci_20', 'PctGE21' : 'act_comp_over_21_20', 'Year' : 'year'}

act_20_ca.rename(columns = act_20_ca_columns_dict, inplace=True)

act_20_ca.head(1)
# Out:
#              CDS record_type                                   SName  \
# 0  1100170112607           S  Envision Academy for Arts & Technology
#
#                              district    CName  students_in_grade_12_20  \
# 0  Alameda County Office of Education  Alameda                       85
#
#    act_test_takers_20  act_eng_20  act_read_20  act_math_20  act_sci_20  \
# 0                   0         NaN          NaN          NaN         NaN
#
#    NumGE21  act_comp_over_21_20     year
# 0      NaN                  NaN  2019-20

# %%
sat_19_ca_columns_dict ={'RType' : 'record_type', 'DName' : 'district', 
                           'Enroll12' : 'students_in_grade_12_19', 'NumTSTTakr12' : 'sat_19_grade_12_takers',
                           'PctERWBenchmark12' : 'sat_19_grade_12_at_erwb_benchmark',
                           'PctMathBenchmark12' : 'sat_19_grade_12_at_math_benchmark', 
                           'Enroll11' : 'students_in_grade_11_19', 'NumTSTTakr11' : 'sat_19_grade_11_takers',
                           'PctERWBenchmark11' : 'sat_19_grade_11_at_erwb_benchmark',
                           'PctMathBenchmark11' : 'sat_19_grade_11_at_math_benchmark', 
                           'PctBothBenchmark12' : 'sat_19_grade_12_at_both_benchmarks',
                           'PctBothBenchmark11' : 'sat_19_grade_11_at_both_benchmarks', 
                           'Year' : 'year'}
sat_19_ca.rename(columns = sat_19_ca_columns_dict, inplace=True)

sat_19_ca.head(1)
# Out:
#             CDS  CCode    CDCode     SCode record_type  \
# 0  6.615981e+12    6.0  661598.0  630046.0           S
#
#                      SName        district   CName  students_in_grade_12_19  \
# 0  Colusa Alternative Home  Colusa Unified  Colusa                     18.0
#
#    sat_19_grade_12_takers  NumERWBenchmark12  \
# 0                     0.0                NaN
#
#    sat_19_grade_12_at_erwb_benchmark  NumMathBenchmark12  \
# 0                                NaN                 NaN
#
#    sat_19_grade_12_at_math_benchmark  students_in_grade_11_19  \
# 0                                NaN                     18.0
#
#    sat_19_grade_11_takers  NumERWBenchmark11  \
# 0                     0.0                NaN
#
#    sat_19_grade_11_at_erwb_benchmark  NumMathBenchmark11  \
# 0                                NaN                 NaN
#
#    sat_19_grade_11_at_math_benchmark  TotNumBothBenchmark12  \
# 0                                NaN                    NaN
#
# ...

# %%
sat_20_ca_columns_dict ={'RType' : 'record_type', 'DName' : 'district', 
                           'Enroll12' : 'students_in_grade_12_20', 'NumTSTTakr12' : 'sat_20_grade_12_takers',
                           'PctERWBenchmark12' : 'sat_20_grade_12_at_erwb_benchmark',
                           'PctMathBenchmark12' : 'sat_20_grade_12_at_math_benchmark', 
                           'Enroll11' : 'students_in_grade_11_20', 'NumTSTTakr11' : 'sat_20_grade_11_takers',
                           'PctERWBenchmark11' : 'sat_20_grade_11_at_erwb_benchmark',
                           'PctMathBenchmark11' : 'sat_20_grade_11_at_math_benchmark', 
                           'PctBothBenchmark12' : 'sat_20_grade_12_at_both_benchmarks',
                           'PctBothBenchmark11' : 'sat_20_grade_11_at_both_benchmarks', 
                           'Year' : 'year'}

sat_20_ca.rename(columns = sat_20_ca_columns_dict, inplace=True)

sat_20_ca.head(1)
# Out:
#               CDS  CCode   CDCode    SCode record_type        SName  \
# 0  19647251930411     19  1964725  1930411           S  Avalon K-12
#
#              district        CName  students_in_grade_12_20  \
# 0  Long Beach Unified  Los Angeles                       39
#
#    sat_20_grade_12_takers  NumERWBenchmark12  \
# 0                      18               0.15
#
#    sat_20_grade_12_at_erwb_benchmark  NumMathBenchmark12  \
# 0                             0.8333                0.07
#
#    sat_20_grade_12_at_math_benchmark  students_in_grade_11_20  \
# 0                             0.3889                       36
#
#    sat_20_grade_11_takers  NumERWBenchmark11  \
# 0                       0                NaN
#
#    sat_20_grade_11_at_erwb_benchmark  NumMathBenchmark11  \
# 0                                NaN                 NaN
#
#    sat_20_grade_11_at_math_benchmark  TotNumBothBenchmark12  \
# 0                                NaN                   0.07
#
# ...

# %%
school_district_equity_columns_dict ={'school_district' : 'district', 
                                      'expenditures_for_public_elementary_and_secondary_schools_per_pupil' : 
                                      'education_spend_per_student', 
                                      'income_by_school_district' : 'avg_household_income'}

school_district_equity.rename(columns = school_district_equity_columns_dict, inplace=True)

school_district_equity.head(1)
# Out:
#       district  score  education_spend_per_student  avg_household_income
# 0  Abc Unified   8.12                        12189                 81101

# %%
district_enrollment_by_ethnicity_columns_dict ={'name' : 'district', 
                                      'american_indian_or_alaska_native' : 
                                      'am_indian_or_alaska_native', 
                                   'two _or_more_races' : 'two_or_more_races'}

district_enrollment_by_ethnicity.rename(columns = district_enrollment_by_ethnicity_columns_dict, inplace=True)

district_enrollment_by_ethnicity.head(1)
# Out:
#                              district  african_american  \
# 0  Alameda County Office of Education             0.171
#
#    am_indian_or_alaska_native  asian  filipino  hispanic_or_latino  \
# 0                       0.004  0.122     0.013               0.481
#
#    pacific_islander  white  two_or_more_races  not_reported
# 0              0.01  0.101              0.086         0.012

# %%
act_19_ca['act_19_participation'] = act_19_ca['act_test_takers_19'] / act_19_ca['students_in_grade_12_19']
act_20_ca['act_20_participation'] = act_20_ca['act_test_takers_20'] / act_20_ca['students_in_grade_12_20']

# %%
sat_19_ca['sat_19_g12_participation'] = sat_19_ca['sat_19_grade_12_takers'] / sat_19_ca['students_in_grade_12_19']
sat_19_ca['sat_19_g11_participation'] = sat_19_ca['sat_19_grade_11_takers'] / sat_19_ca['students_in_grade_11_19']

# %%
sat_20_ca['sat_20_g12_participation'] = sat_20_ca['sat_20_grade_12_takers'] / sat_20_ca['students_in_grade_12_20']
sat_20_ca['sat_20_g11_Participation'] = sat_20_ca['sat_20_grade_11_takers'] / sat_20_ca['students_in_grade_11_20']

# %% [markdown]
# Converting sat_19_grade_11_at_both_benchmarks to percentages.

# %%
sat_19_ca['sat_19_grade_11_at_both_benchmarks'] = (sat_19_ca['sat_19_grade_11_at_both_benchmarks']/100)

# %%
act_19_ca.shape
# Out:
# (2310, 18)

# %% [markdown]
# # Drop unnecessary rows (if needed)

# %% [markdown]
# Pairing down my lists by focusing on school districts instead of individual schools.

# %%
act_19_ca.drop(act_19_ca[act_19_ca['record_type'] != 'D'].index, inplace=True)
act_19_ca.drop(columns=['CDS', 'CCode', 'record_type', 'SCode', 'CDCode', 'SName', 'CName', 'NumGE21', 'year'], inplace=True)
act_19_ca.shape
# Out:
# (522, 9)

# %%
act_20_ca.drop(act_20_ca[act_20_ca['record_type'] != 'D'].index, inplace=True)
act_20_ca = act_20_ca[act_20_ca['district'].notna()]
act_20_ca.drop(columns=['CDS', 'SName', 'record_type', 'CName', 'NumGE21', 'year'], inplace=True)

act_20_ca.shape
# Out:
# (522, 9)

# %%
sat_19_ca.shape
# Out:
# (2580, 27)

# %%
sat_19_ca.drop(sat_19_ca[sat_19_ca['record_type'] != 'D'].index, inplace=True)

# %%
sat_19_ca.shape
# Out:
# (539, 27)

# %%
sat_19_ca.drop(columns=['CDS', 'CCode', 'record_type','SCode', 'CDCode', 'SName', 'CName', 'NumERWBenchmark12', 
                          'NumMathBenchmark12', 'NumERWBenchmark11', 'NumMathBenchmark11', 'TotNumBothBenchmark12',
                          'TotNumBothBenchmark11', 'year'], inplace=True)

# %%
sat_19_ca.shape
# Out:
# (539, 13)

# %%
sat_20_ca.shape
# Out:
# (2482, 27)

# %%
sat_20_ca.drop(sat_20_ca[sat_20_ca['record_type'] != 'D'].index, inplace=True)
sat_20_ca.drop(columns=['CDS', 'CCode', 'SCode', 'record_type', 'CDCode', 'SName', 'CName', 'NumERWBenchmark12', 
                          'NumMathBenchmark12', 'NumERWBenchmark11', 'NumMathBenchmark11', 'TotNumBothBenchmark12',
                          'TotNumBothBenchmark11', 'year'], inplace=True)

sat_20_ca.shape
# Out:
# (532, 13)

# %%
act_19_ca.apply(lambda x: x.str.lower() if(x.dtype == 'object') else x)
# Out:
#                                 district  students_in_grade_12_19  \
# 1122  alameda county office of education                    170.0
# 1123                     alameda unified                    919.0
# 1124                 albany city unified                    307.0
# 1125                    berkeley unified                    820.0
# 1126               castro valley unified                    737.0
# ...                                  ...                      ...
# 1639              woodland joint unified                    767.0
# 1640     yuba county office of education                    166.0
# 1641             camptonville elementary                     42.0
# 1642            marysville joint unified                    602.0
# 1643                wheatland union high                    167.0
#
#       act_test_takers_19  act_read_19  act_eng_19  act_math_19  act_sci_19  \
# 1122                 0.0          NaN         NaN          NaN         NaN
# ...

# %%
act_20_ca.apply(lambda x: x.str.lower() if(x.dtype == 'object') else x)
# Out:
#                                 district  students_in_grade_12_20  \
# 1767  alameda county office of education                      216
# 1768                     alameda unified                      928
# 1769                 albany city unified                      258
# 1770                    berkeley unified                      825
# 1771               castro valley unified                      781
# ...                                  ...                      ...
# 2284              woodland joint unified                      749
# 2285     yuba county office of education                       88
# 2286             camptonville elementary                       44
# 2287            marysville joint unified                      641
# 2288                wheatland union high                      219
#
#       act_test_takers_20  act_eng_20  act_read_20  act_math_20  act_sci_20  \
# 1767                   0         NaN          NaN          NaN         NaN
# ...

# %%
sat_19_ca.apply(lambda x: x.str.lower() if(x.dtype == 'object') else x)
# Out:
#                           district  students_in_grade_12_19  \
# 2037               fremont unified                   2537.0
# 2038         piedmont city unified                    231.0
# 2039           san leandro unified                    754.0
# 2040                fresno unified                   4593.0
# 2041               mendota unified                    234.0
# ...                            ...                      ...
# 2571    oak grove union elementary                     70.0
# 2572  hart-ransom union elementary                     18.0
# 2573                   keyes union                     25.0
# 2574             riverbank unified                    179.0
# 2575           davis joint unified                    717.0
#
#       sat_19_grade_12_takers  sat_19_grade_12_at_erwb_benchmark  \
# 2037                   845.0                             0.9077
# 2038                    78.0                             0.8718
# ...

# %%
sat_20_ca.apply(lambda x: x.str.lower() if(x.dtype == 'object') else x)
# Out:
#                                      district  students_in_grade_12_20  \
# 1916                    castro valley unified                      781
# 1917                          maxwell unified                       26
# 1918  contra costa county office of education                      899
# 1919                 san ramon valley unified                     2748
# 1920                           sanger unified                      857
# ...                                       ...                      ...
# 2443                 harmony union elementary                       55
# 2444                    sonoma valley unified                      320
# 2445                          lindsay unified                      264
# 2446       ventura county office of education                      334
# 2447                          pleasant valley                      109
#
#       sat_20_grade_12_takers  sat_20_grade_12_at_erwb_benchmark  \
# ...

# %%
school_district_equity.apply(lambda x: x.str.lower() if(x.dtype == 'object') else x)
# Out:
#                            district  score  education_spend_per_student  \
# 0                       abc unified   8.12                        12189
# 1               acalanes union high  77.56                        15267
# 2          acton-agua dulce unified  32.54                        14318
# 3               adelanto elementary  30.62                        12993
# 4                   alameda unified  32.25                        13436
# ..                              ...    ...                          ...
# 917                yosemite unified  20.74                        12509
# 918          yreka union elementary  57.24                        12083
# 919                yreka union high  32.74                        15302
# 920               yuba city unified  32.60                        13243
# 921  yucaipa-calimesa joint unified  26.99                        11758
#
#      avg_household_income
# 0                   81101
# 1                  129146
# ...

# %%
district_enrollment_by_ethnicity.apply(lambda x: x.str.lower() if(x.dtype == 'object') else x)
# Out:
#                                                district  african_american  \
# 0                    alameda county office of education             0.171
# 1                                       alameda unified             0.065
# 2                                   albany city unified             0.034
# 3                                      berkeley unified             0.127
# 4     california school for the blind (state special...             0.138
# ...                                                 ...               ...
# 1024                           marysville joint unified             0.037
# 1025                             plumas lake elementary             0.035
# 1026                                          wheatland             0.031
# 1027                               wheatland union high             0.034
# 1028                    yuba county office of education             0.024
#
#       am_indian_or_alaska_native  asian  filipino  hispanic_or_latino  \
# ...

# %% [markdown]
# # Merging dataframes

# %%
equity_and_ethnicity = pd.merge(school_district_equity, district_enrollment_by_ethnicity, how='left')
act_19_20_ca = pd.merge(act_19_ca, act_20_ca, how='right')
sat_19_20_ca = pd.merge(sat_19_ca, sat_20_ca, how='right')
sat_and_act_19_20 = pd.merge(act_19_20_ca, sat_19_20_ca, how='right')
act_19_ca = pd.merge(act_19_ca, equity_and_ethnicity, how='left')
act_20_ca = pd.merge(act_20_ca, equity_and_ethnicity, how='left')
sat_19_ca = pd.merge(sat_19_ca, equity_and_ethnicity, how='left')
sat_20_ca = pd.merge(sat_20_ca, equity_and_ethnicity, how='left')

# %% [markdown]
# # COME BACK TO THIS!!!!!!!!!

# %% [markdown]
# Due to issues with NaN values that prevented my standard deviation function to perform accurate calculations, and in an effort to make the data more manageable, I've decided to elimated rows with NaN values.

# %%
# act_19_ca.dropna(inplace=True)
# act_20_ca.dropna(inplace=True)
# sat_19_ca.dropna(inplace=True)
# sat_20_ca.dropna(inplace=True)
# equity_and_ethnicity.dropna(inplace=True)

# %%
act_19_ca.fillna(0, inplace=True)
act_20_ca.fillna(0, inplace=True)
sat_19_ca.fillna(0, inplace=True)
sat_20_ca.fillna(0, inplace=True)
equity_and_ethnicity.fillna(0, inplace=True)

# %% [markdown]
# # Saving dataframes

# %%
act_19_ca.to_csv('../data/act_19_ca.csv')
act_20_ca.to_csv('../data/act_20_ca.csv')
act_19_20_ca.to_csv('../data/act_19_20_ca.csv')
sat_19_ca.to_csv('../data/sat_19_ca.csv')
sat_20_ca.to_csv('../data/sat_20_ca.csv')
sat_19_20_ca.to_csv('../data/sat_19_20_ca.csv')
sat_and_act_19_20.to_csv('../data/sat_and_act_19_20')
equity_and_ethnicity.to_csv('../data/equity_and_ethnicity.csv')

# %% [markdown]
# ---
# # Data Dictionary
# ---

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**district**|*object*|California SAT|California school district name for the associated ACT/SAT test scores, averages, participation rates as well as economic and demographic data|
# |**grade_12_at_erwb_benchmark**|*float*|California SAT|The percentage of students who met or exceeded the benchmark for Evidence-Based Reading & Writing (ERW) test for Grade 12 (range: 0-1)|
# |**grade_12_at_math_benchmark**|*float*|California SAT|The percentage of students who met or exceeded the benchmark for SAT Math test for Grade 12 (range: 0-1)|
# |**grade_11_at_erwb_benchmark**|*float*|California SAT|The percentage of students who met or exceeded the benchmark for Evidence-Based Reading & Writing (ERW) test for Grade 11 (range: 0-1)|
# |**grade_11_at_math_benchmark**|*float*|California SAT|The percentage of students who met or exceeded the benchmark for SAT Math test for Grade 11 (range: 0-1)|
# |**grade_12_at_both_benchmarks**|*float*|California SAT|The percentage of students who met the benchmark of both Evidence-Based Reading & Writing (ERW) and Math Grade 12 (range: 0-1)|
# |**grade_11_at_both_benchmarks**|*float*|California SAT|The percentage of students who met the benchmark of both Evidence-Based Reading & Writing (ERW) and Math Grade 11 (range: 0-1)|
# |**sat_g12_Participation**|*float*|California SAT|The percentage of students who wrote the SAT for Grade 12 (range: 0-1)|
# |**sat_g11_Participation**|*float*|California SAT|The percentage of students who wrote the SAT for Grade 12 (range: 0-1)|
# |**grade_12_takers**|*float*|California SAT|The total numner of Grade 12 students who wrote the SAT|
# |**grade_11_takers**|*float*|California SAT|The total numner of Grade 11 students who wrote the SAT|
# |**act_read**|*float*|California ACT|Average ACT Reading Score (range: 0-36)|
# |**act_eng**|*float*|California ACT|Average ACT English Score (range: 0-36)|
# |**act_math**|*float*|California ACT|Average ACT Math Score (range: 0-36)|
# |**act_sci**|*float*|California ACT|Average ACT Science Score (range: 0-36)|
# |**act_comp_over_21**|*float*|California ACT|The percentage of test takers whose ACT Composite Scores are greater or equal to 21 (range: 0-1)|
# |**act_participation**|*float*|California ACT|The percentage of grade 12 students who wrote the ACT (range: 0-1)|
# |**students_in_grade_12**|*float*|California ACT|The total number of grade 12 students in the district (range: 0-1)|
# |**education_spend_per_student**|*float*|School District Equity|Expenditure for public elementary and secondary schools per pupil|
# |**avg_household_income**|*float*|School District Equity|Average household income|
# |**african_american**|*float*|District Enrollment by Ethnicity|The percentage of students who identify as African America (range: 0-1)|
# |**am_indian_or_alaska_native**|*float*|District Enrollment by Ethnicity|The percentage of students who identify as American Indian or Alaska Native (range: 0-1)|
# |**asian**|*float*|District Enrollment by Ethnicity|The percentage of students who identify as Asian (range: 0-1)|
# |**filipino**|*float*|District Enrollment by Ethnicity|The percentage of students who identify as Filipino (range: 0-1)|
# |**hispanic_or_latino**|*float*|District Enrollment by Ethnicity|The percentage of students who identify as Hispanic or Latino (range: 0-1)|
# |**pacific_islander**|*float*|District Enrollment by Ethnicity|The percentage of students who identify as Pacific Islander (range: 0-1)|
# |**white**|*float*|District Enrollment by Ethnicity|The percentage of students who identify as white (range: 0-1)|
# |**two_or_more_races**|*float*|District Enrollment by Ethnicity|The percentage of students who identify as two or more ethnic backgrounds (range: 0-1)|
# |**not_reported**|*float*|District Enrollment by Ethnicity|The percentage of students whose ethnic background is unknown (range: 0-1)|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# # Summary Statistics

# %%
act_19_ca.describe()
# Out:
#        students_in_grade_12_19  act_test_takers_19  act_read_19  act_eng_19  \
# count               326.000000          326.000000   326.000000  326.000000
# mean               1366.134969          242.849693    22.570552   21.680982
# std                2670.590006          581.863197     3.262787    3.652111
# min                  20.000000           15.000000    15.000000   14.000000
# 25%                 295.250000           41.000000    20.000000   19.000000
# 50%                 742.000000          115.000000    23.000000   22.000000
# 75%                1659.000000          257.750000    25.000000   24.000000
# max               41873.000000         9336.000000    30.000000   31.000000
#
#        act_math_19  act_sci_19  act_comp_over_21_19  act_19_participation  \
# count   326.000000  326.000000           326.000000            326.000000
# mean     21.779141   21.779141             0.557515              0.200177
# ...

# %%
act_20_ca.describe()
# Out:
#        students_in_grade_12_20  act_test_takers_20  act_eng_20  act_read_20  \
# count               298.000000          298.000000  298.000000   298.000000
# mean               1470.708054          211.681208   22.053691    23.127517
# std                2728.110205          439.443774    3.776206     3.342993
# min                  51.000000           15.000000   14.000000    16.000000
# 25%                 346.750000           41.250000   19.000000    20.000000
# 50%                 853.500000          104.000000   22.000000    23.000000
# 75%                1832.750000          250.250000   25.000000    26.000000
# max               41110.000000         6681.000000   31.000000    30.000000
#
#        act_math_20  act_sci_20  act_comp_over_21_20  act_20_participation  \
# count   298.000000  298.000000           298.000000            298.000000
# mean     22.208054   22.181208             0.593456              0.167409
# ...

# %%
sat_19_ca.describe()
# Out:
#        students_in_grade_12_19  sat_19_grade_12_takers  \
# count                357.00000              357.000000
# mean                1270.29972              457.008403
# std                 2571.37235             1174.896052
# min                   45.00000               16.000000
# 25%                  251.00000               62.000000
# 50%                  639.00000              204.000000
# 75%                 1560.00000              492.000000
# max                41873.00000            19988.000000
#
#        sat_19_grade_12_at_erwb_benchmark  sat_19_grade_12_at_math_benchmark  \
# count                         357.000000                         357.000000
# mean                            0.734960                           0.503655
# std                             0.155398                           0.201356
# min                             0.315800                           0.000000
# 25%                             0.630400                           0.346900
# ...

# %%
sat_20_ca.describe()
# Out:
#        students_in_grade_12_20  sat_20_grade_12_takers  \
# count               235.000000              235.000000
# mean               1728.089362              604.744681
# std                3010.002694             1237.582163
# min                  75.000000               18.000000
# 25%                 514.000000              155.000000
# 50%                1057.000000              332.000000
# 75%                2078.500000              681.000000
# max               41110.000000            17095.000000
#
#        sat_20_grade_12_at_erwb_benchmark  sat_20_grade_12_at_math_benchmark  \
# count                         235.000000                         235.000000
# mean                            0.747609                           0.553894
# std                             0.153343                           0.209377
# min                             0.281300                           0.088200
# 25%                             0.651100                           0.388850
# ...

# %%
equity_and_ethnicity.describe()
# Out:
#             score  education_spend_per_student  avg_household_income  \
# count  886.000000                   886.000000            886.000000
# mean    41.680395                 14761.040632          74383.767494
# std     46.179128                  6447.148333          33917.758995
# min      0.050000                   287.000000          20583.000000
# 25%     16.827500                 11864.250000          50358.500000
# 50%     32.045000                 13246.500000          66286.000000
# 75%     49.657500                 15072.750000          90346.500000
# max    502.260000                 86000.000000         250000.000000
#
#        african_american  am_indian_or_alaska_native       asian    filipino  \
# count        886.000000                  886.000000  886.000000  886.000000
# mean           0.024959                    0.017893    0.056198    0.013133
# std            0.042662                    0.063255    0.104762    0.024414
# ...

# %% [markdown]
# # Use a dictionary comprehension to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.

# %%
sd = {i:calculate_std(act_19_ca[i]) for i in act_19_ca.columns if (act_19_ca[i].dtype==float)}
#https://stackoverflow.com/questions/55048445/dictionary-comprehension-to-apply-a-function-to-dataframe-columns

sd
# Out:
# {'students_in_grade_12_19': 2666.4908628496332,
#  'act_test_takers_19': 580.970083691129,
#  'act_read_19': 3.2577784691456726,
#  'act_eng_19': 3.6465052123183574,
#  'act_math_19': 3.1350473619524037,
#  'act_sci_19': 2.8928185671241464,
#  'act_comp_over_21_19': 0.23180465267985298,
#  'act_19_participation': 0.16603738311333163,
#  'score': 28.66179926330929,
#  'education_spend_per_student': 2536.049093573554,
#  'avg_household_income': 28965.93737782873,
#  'african_american': 0.0500645257172483,
#  'am_indian_or_alaska_native': 0.016257038996949105,
#  'asian': 0.12261264495280348,
#  'filipino': 0.03015903263412176,
#  'hispanic_or_latino': 0.25706688956898477,
#  'pacific_islander': 0.005966784401181284,
#  'white': 0.20664914801481607,
#  'two_or_more_races': 0.034474268889661513,
#  'not_reported': 0.011546033458708067}

# %%
act_19_ca.describe()
# Out:
#        students_in_grade_12_19  act_test_takers_19  act_read_19  act_eng_19  \
# count               326.000000          326.000000   326.000000  326.000000
# mean               1366.134969          242.849693    22.570552   21.680982
# std                2670.590006          581.863197     3.262787    3.652111
# min                  20.000000           15.000000    15.000000   14.000000
# 25%                 295.250000           41.000000    20.000000   19.000000
# 50%                 742.000000          115.000000    23.000000   22.000000
# 75%                1659.000000          257.750000    25.000000   24.000000
# max               41873.000000         9336.000000    30.000000   31.000000
#
#        act_math_19  act_sci_19  act_comp_over_21_19  act_19_participation  \
# count   326.000000  326.000000           326.000000            326.000000
# mean     21.779141   21.779141             0.557515              0.200177
# ...

# %% [markdown]
# # Investigate trends in the data

# %%
act_20_ca[['district', 'act_20_participation', 'education_spend_per_student', 'avg_household_income',
           'white', 'hispanic_or_latino']].sort_values('act_20_participation', ascending=False).head(10)
# Out:
#                        district  act_20_participation  \
# 152                   Hawthorne              0.951613
# 478         Los Molinos Unified              0.870968
# 157                      Lennox              0.653979
# 118         Reef-Sunset Unified              0.629032
# 276                Nuview Union              0.592857
# 446                    Roseland              0.589744
# 249        Laguna Beach Unified              0.571429
# 479  Red Bluff Joint Union High              0.505882
# 227              Carmel Unified              0.484163
# 12        Piedmont City Unified              0.471429
#
#      education_spend_per_student  avg_household_income  white  \
# 152                      13250.0               50580.0  0.021
# 478                      14423.0               45326.0  0.401
# 157                      14978.0               49978.0  0.005
# 118                      13896.0               42136.0  0.021
# ...

# %% [markdown]
# Highest ACT Participation Rates for 2020:
# - Hawthorne
# - Los Molinos Unified
# - Lennox
# - Reef-Sunset Unified
# - Nuview Union
# - Roseland
# - Laguna Beach Unified
# - Red Bluff Joint Union High
# - Carmel Unified
# - Piedmont City Unified

# %%
act_20_ca[['district', 'act_20_participation', 'education_spend_per_student', 'avg_household_income', 
           'white', 'hispanic_or_latino']].sort_values('act_20_participation', ascending=False).tail(10)
# Out:
#                         district  act_20_participation  \
# 90              Calexico Unified              0.035539
# 166            Paramount Unified              0.030000
# 385  South San Francisco Unified              0.028658
# 135           Bellflower Unified              0.026052
# 142        Covina-Valley Unified              0.024119
# 454                Ceres Unified              0.022727
# 269             Beaumont Unified              0.022427
# 67               Central Unified              0.021467
# 286            Val Verde Unified              0.019551
# 281          San Jacinto Unified              0.018801
#
#      education_spend_per_student  avg_household_income  white  \
# 90                       13961.0               43504.0  0.004
# 166                      13949.0               59304.0  0.010
# 385                      13184.0              106209.0  0.064
# 135                      13391.0               65982.0  0.083
# ...

# %% [markdown]
# Lowest ACT Participation Rates for 2020:
# - Calexico Unified
# - Paramount Unified
# - South San Francisco Unified
# - Bellflower Unified
# - Covina-Valley Unified
# - Ceres Unified
# - Beaumont Unified
# - Central Unified
# - Val Verde Unified
# - San Jacinto Unified

# %%
act_20_ca[['district', 'act_comp_over_21_20', 'education_spend_per_student', 'avg_household_income', 
           'white', 'hispanic_or_latino']].sort_values('act_comp_over_21_20', ascending=False).head(10)
# Out:
#                           district  act_comp_over_21_20  \
# 136          Beverly Hills Unified                 1.00
# 413     San Lorenzo Valley Unified                 1.00
# 509               Oak Park Unified                 0.96
# 513            Davis Joint Unified                 0.95
# 402             Fremont Union High                 0.95
# 12           Piedmont City Unified                 0.95
# 154              La Canada Unified                 0.94
# 180          Walnut Valley Unified                 0.94
# 249           Laguna Beach Unified                 0.94
# 404  Los Gatos-Saratoga Union High                 0.94
#
#      education_spend_per_student  avg_household_income  white  \
# 136                      19769.0              106857.0  0.689
# 413                      11012.0               98013.0  0.589
# 509                      10394.0              132665.0  0.532
# 513                      12987.0               67918.0  0.490
# ...

# %% [markdown]
# Highest percentage of test takers with ACT composite scores were greater or equal to 21:
# - Beverly Hills Unified
# - San Lorenzo Valley Unified
# - Oak Park Unified
# - Piedmont City Unified
# - Davis Joint Unified
# - Fremont Union High
# - La Canada Unified
# - Walnut Valley Unified
# - Laguna Beach Unified
# - Los Gatos-Saratoga Union High

# %%
act_20_ca[['district', 'act_comp_over_21_20', 'education_spend_per_student', 'avg_household_income', 
           'white', 'hispanic_or_latino']].sort_values('act_comp_over_21_20', ascending=False).tail(10)
# Out:
#                                    district  act_comp_over_21_20  \
# 228  South Monterey County Joint Union High                 0.14
# 177                         Compton Unified                 0.13
# 69                          Mendota Unified                 0.11
# 486              Cutler-Orosi Joint Unified                 0.10
# 118                     Reef-Sunset Unified                 0.10
# 237                 Calistoga Joint Unified                 0.10
# 114                  Corcoran Joint Unified                 0.10
# 491                    Farmersville Unified                 0.09
# 221                     Modoc Joint Unified                 0.09
# 123                      Upper Lake Unified                 0.07
#
#      education_spend_per_student  avg_household_income  white  \
# 228                      13241.0               57181.0  0.038
# 177                      15206.0               54613.0  0.002
# ...

# %% [markdown]
# Lowest percentage of test takers with ACT composite scores were greater or equal to 21:
# - Upper Lake Unified
# - Farmersville Unified
# - Modoc Joint Unified
# - Reef-Sunset Unified
# - Calistoga Joint Unified
# - Corcoran Joint Unified
# - Cutler-Orosi Joint Unified
# - Mendota Unified
# - Compton Unified
# - South Monterey County Joint Union High

# %%
sat_20_ca[['district', 'sat_20_g12_participation', 'education_spend_per_student', 'avg_household_income', 
           'white', 'hispanic_or_latino']].sort_values('sat_20_g12_participation', ascending=False).head(10)
# Out:
#                   district  sat_20_g12_participation  \
# 474  Covina-Valley Unified                  0.864564
# 453        Fontana Unified                  0.847400
# 240      Val Verde Unified                  0.795860
# 413  Moreno Valley Unified                  0.789970
# 12          Orange Unified                  0.778810
# 166           Nuview Union                  0.757143
# 125       Wasco Union High                  0.748148
# 174   Jefferson Union High                  0.746135
# 275       Stockton Unified                  0.739855
# 127        Lynwood Unified                  0.728945
#
#      education_spend_per_student  avg_household_income  white  \
# 474                      13698.0               73801.0  0.069
# 453                      15045.0               63253.0  0.038
# 240                      13534.0               70358.0  0.042
# 413                      14013.0               64003.0  0.063
# 12                       11918.0               97336.0  0.255
# ...

# %% [markdown]
# Highest Grade 12 SAT Participation Rates for 2020:
# - Covina-Valley Unified
# - Fontana Unified
# - Val Verde Unified
# - Moreno Valley Unified
# - Orange Unified
# - Nuview Union
# - Wasco Union High
# - Jefferson Union High
# - Stockton Unified
# - Lynwood Unified

# %%
sat_20_ca[['district', 'sat_20_g12_participation', 'education_spend_per_student', 'avg_household_income', 
           'white', 'hispanic_or_latino']].sort_values('sat_20_g12_participation', ascending=False).tail(10)
# Out:
#                     district  sat_20_g12_participation  \
# 301     Orland Joint Unified                  0.166667
# 295          Antioch Unified                  0.163830
# 229           Madera Unified                  0.159041
# 509     Sierra Sands Unified                  0.158333
# 379        Shasta Union High                  0.155538
# 181        Yuba City Unified                  0.151822
# 322  Mountain Empire Unified                  0.135501
# 82            Lompoc Unified                  0.125000
# 293        Calaveras Unified                  0.122642
# 86        Corning Union High                  0.070588
#
#      education_spend_per_student  avg_household_income  white  \
# 301                      12312.0               48881.0  0.291
# 295                      13551.0               75642.0  0.121
# 229                      13001.0               50878.0  0.051
# 509                      12280.0               68347.0  0.542
# ...

# %% [markdown]
# Lowest Grade 12 SAT Participation Rates for 2020:
# - Corning Union High
# - Antioch Unified
# - Calaveras Unified
# - Lompoc Unified
# - Mountain Empire Unified
# - Orland Joint Unified
# - Yuba City Unified
# - Shasta Union High
# - Sierra Sands Unified
# - Madera Unified

# %%
sat_19_ca[['district', 'sat_19_grade_12_at_both_benchmarks', 'education_spend_per_student', 'avg_household_income', 
           'white', 'hispanic_or_latino']].sort_values('sat_19_grade_12_at_both_benchmarks', ascending=False).head(10)
# Out:
#                     district  sat_19_grade_12_at_both_benchmarks  \
# 517        La Canada Unified                              0.9176
# 38        San Marino Unified                              0.9167
# 368        Palo Alto Unified                              0.9046
# 173           Irvine Unified                              0.8809
# 518   South Pasadena Unified                              0.8785
# 448  Manhattan Beach Unified                              0.8732
# 538      Davis Joint Unified                              0.8730
# 505       Fremont Union High                              0.8702
# 132         Oak Park Unified                              0.8690
# 197      Albany City Unified                              0.8421
#
#      education_spend_per_student  avg_household_income  white  \
# 517                      12010.0              186500.0  0.446
# 38                       14406.0              156429.0  0.227
# ...

# %% [markdown]
# Highest percentage of grade 12 students at or above SAT benchmarks for math and evidence-based reading & writing for 2019:
# - Fremont Unified
# - Simi Valley Unified
# - Oceanside Unified
# - Santa Ynez Valley Union High
# - Dublin Unified
# - Liberty Union High
# - El Segundo Unified
# - Corona-Norco Unified
# - San Juan Unified
# - Lompoc Unified

# %%
sat_20_ca[['district', 'sat_20_grade_12_at_both_benchmarks', 'education_spend_per_student', 'avg_household_income', 
           'white', 'hispanic_or_latino']].sort_values('sat_20_grade_12_at_both_benchmarks', ascending=False).tail(10)
# Out:
#                   district  sat_20_grade_12_at_both_benchmarks  \
# 229         Madera Unified                              0.1781
# 275       Stockton Unified                              0.1567
# 453        Fontana Unified                              0.1550
# 413  Moreno Valley Unified                              0.1541
# 240      Val Verde Unified                              0.1503
# 392         Fowler Unified                              0.1463
# 394      Caruthers Unified                              0.1250
# 45         Compton Unified                              0.1002
# 127        Lynwood Unified                              0.0956
# 448        Soledad Unified                              0.0882
#
#      education_spend_per_student  avg_household_income  white  \
# 229                      13001.0               50878.0  0.051
# 275                      15106.0               44393.0  0.047
# 453                      15045.0               63253.0  0.038
# ...

# %% [markdown]
# Lowest percentage of grade 12 students at or above SAT benchmarks for math and evidence-based reading & writing for 2020:
# - Sonoma Valley Unified
# - Perris Union High
# - Linden Unified
# - Oakland Unified
# - Riverdale Joint Unified
# - Val Verde Unified
# - Riverside Unified
# - El Monte Union High
# - Madera Unified
# - Pasadena Unified

# %%
no_small_districts = sat_20_ca['students_in_grade_12_20'] > 1000
sat_20_ca[no_small_districts][['district', 'sat_20_grade_12_at_both_benchmarks', 'education_spend_per_student', 'avg_household_income', 
           'white', 'hispanic_or_latino']].sort_values('sat_20_grade_12_at_both_benchmarks', ascending=False).head(10)
# Out:
#                      district  sat_20_grade_12_at_both_benchmarks  \
# 177         Palo Alto Unified                              0.9050
# 265            Irvine Unified                              0.8801
# 327        Fremont Union High                              0.8767
# 184       Acalanes Union High                              0.8568
# 149        Pleasanton Unified                              0.8449
# 274             Poway Unified                              0.8357
# 100     Walnut Valley Unified                              0.8326
# 3    San Ramon Valley Unified                              0.8313
# 491   San Dieguito Union High                              0.8311
# 130      Tamalpais Union High                              0.8234
#
#      education_spend_per_student  avg_household_income  white  \
# 177                      23038.0              151578.0  0.339
# 265                      11451.0              106905.0  0.256
# ...

# %% [markdown]
# Highest percentage of grade 12 students at or above both SAT benchmarks in districts with more than 1000 people:
# - Palo Alto Unified
# - Irvine Unified
# - Fremont Union High
# - Acalanes Union High
# - Pleasanton Unified
# - Poway Unified
# - Walnut Valley Unified
# - San Ramon Valley Unified
# - San Dieguito Union High
# - Tamalpais Union High

# %%
sat_20_ca[no_small_districts][['district', 'sat_20_grade_12_at_both_benchmarks', 'education_spend_per_student', 'avg_household_income', 
           'white', 'hispanic_or_latino']].sort_values('sat_20_grade_12_at_both_benchmarks', ascending=False).tail(10)
# Out:
#                       district  sat_20_grade_12_at_both_benchmarks  \
# 474      Covina-Valley Unified                              0.2221
# 468  West Contra Costa Unified                              0.2194
# 15               Hemet Unified                              0.1851
# 229             Madera Unified                              0.1781
# 275           Stockton Unified                              0.1567
# 453            Fontana Unified                              0.1550
# 413      Moreno Valley Unified                              0.1541
# 240          Val Verde Unified                              0.1503
# 45             Compton Unified                              0.1002
# 127            Lynwood Unified                              0.0956
#
#      education_spend_per_student  avg_household_income  white  \
# 474                      13698.0               73801.0  0.069
# 468                      14231.0               78737.0  0.101
# ...

# %% [markdown]
# Lowest percentage of grade 12 students at or above both SAT benchmarks in districts with more than 1000 people:
# Covina-Valley Unified
# - West Contra Costa Unified
# - Hemet Unified
# - Madera Unified
# - Stockton Unified
# - Fontana Unified
# - Moreno Valley Unified
# - Val Verde Unified
# - Compton Unified
# - Lynwood Unified

# %%
act_no_small_districts = act_20_ca['students_in_grade_12_20'] > 1000
act_20_ca[act_no_small_districts][['district', 'act_comp_over_21_20', 'education_spend_per_student', 'avg_household_income', 
           'white', 'hispanic_or_latino']].sort_values('act_comp_over_21_20', ascending=False).head(10)
# Out:
#                                district  act_comp_over_21_20  \
# 402                  Fremont Union High                 0.95
# 256                      Irvine Unified                 0.94
# 180               Walnut Valley Unified                 0.94
# 6                       Fremont Unified                 0.93
# 16                   Pleasanton Unified                 0.92
# 43             San Ramon Valley Unified                 0.91
# 406  Mountain View-Los Altos Union High                 0.91
# 34                  Acalanes Union High                 0.91
# 201                Tamalpais Union High                 0.91
# 149                    Glendale Unified                 0.89
#
#      education_spend_per_student  avg_household_income  white  \
# 402                      15994.0              154876.0  0.154
# 256                      11451.0              106905.0  0.256
# 180                      11162.0              104237.0  0.056
# ...

# %% [markdown]
# Highest percentage of grade 12 students with a composite ACT score of at least 21 in districts with more than 1000 people:
# - Fremont Union High
# - Irvine Unified
# - Walnut Valley Unified
# - Fremont Unified
# - Pleasanton Unified
# - San Ramon Valley Unified
# - Mountain View-Los Altos Union High
# - Acalanes Union High
# - Tamalpais Union High
# - Glendale Unified

# %%
act_20_ca[act_no_small_districts][['district', 'act_comp_over_21_20', 'education_spend_per_student', 'avg_household_income', 
           'white', 'hispanic_or_latino']].sort_values('act_comp_over_21_20', ascending=False).tail(10)
# Out:
#                         district  act_comp_over_21_20  \
# 436         Vallejo City Unified                 0.27
# 286            Val Verde Unified                 0.26
# 316  San Bernardino City Unified                 0.25
# 275        Moreno Valley Unified                 0.24
# 279            Perris Union High                 0.24
# 307         Colton Joint Unified                 0.23
# 194               Madera Unified                 0.22
# 160              Lynwood Unified                 0.21
# 282     Coachella Valley Unified                 0.17
# 177              Compton Unified                 0.13
#
#      education_spend_per_student  avg_household_income  white  \
# 436                      13268.0               69300.0  0.065
# 286                      13534.0               70358.0  0.042
# 316                      15714.0               46743.0  0.048
# 275                      14013.0               64003.0  0.063
# ...

# %% [markdown]
# Highest percentage of grade 12 students with a composite ACT score of at least 21 in districts with more than 1000 people:
# - Vallejo City Unified
# - Val Verde Unified
# - San Bernardino City Unified
# - Moreno Valley Unified
# - Perris Union High
# - Colton Joint Unified
# - Madera Unified
# - Lynwood Unified
# - Coachella Valley Unified
# - Compton Unified

# %% [markdown]
# # TRENDS

# %% [markdown]
# Coming into this, I assumed that the data would validate my hypothesis that race and wealth did play a factor in how well students did on standardized testing
#
# Initially though, I started to question my assumptions.
#
# While there was some data to support that supported my assumption, it seemed to be minimal and more the sort of thing that could be potentially be explained away by other factors.
#
# When I filtered for district size however, the difference was startling.
#
# A trend became painfully obvious.
#
# The students scoring highest on standardized test weren't just a little better off financially than their peers.
#
# They were A LOT better off.
#
# The correlation between wealth and scors is undeniable.
#
# Additionally, there is an overrepresentation of white students on the higher score and participation spectrum.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# # Use Seaborn's heatmap with pandas .corr() to visualize correlations between all numeric features

# %% [markdown]
# ## CHANGE THE TITLE OF BELOW AND COMMENT

# %%
plt.figure(figsize=(15 , 10))

correlation = equity_and_ethnicity.corr()

mask = np.zeros_like(correlation)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(correlation, annot=True, mask=mask, cmap="mako")

plt.title("If you do well on one, you are likely to do well on the other");

# %%
sat_and_act_total

# %%
sat_and_act_total = sat_and_act_19_20[sat_and_act_19_20['students_in_grade_12_20']>1000] [['act_comp_over_21_20', 'sat_20_grade_12_at_both_benchmarks', 'act_20_participation', 
                                                                                     'sat_20_g12_participation', 'sat_20_g11_Participation']]
sat_and_act_total
# Out:
#      act_comp_over_21_20  sat_20_grade_12_at_both_benchmarks  \
# 3                   0.91                              0.8313
# 7                   0.65                              0.4972
# 12                  0.83                              0.3001
# 15                  0.37                              0.1851
# 18                  0.36                              0.2946
# 20                  0.53                              0.5815
# 39                  0.35                              0.2768
# 42                   NaN                              0.3611
# 43                  0.39                              0.2792
# 45                  0.32                              0.3754
# 46                  0.13                              0.1002
# 47                  0.80                              0.5596
# 48                  0.33                              0.2380
# 49                  0.37                              0.3179
# ...

# %%
combined = pd.concat([sat_and_act_total, equity_and_ethnicity], axis=1).dropna() 
combined.head()
# Out:
#     act_comp_over_21_20  sat_20_grade_12_at_both_benchmarks  \
# 3                  0.91                              0.8313
# 7                  0.65                              0.4972
# 12                 0.83                              0.3001
# 15                 0.37                              0.1851
# 18                 0.36                              0.2946
#
#     act_20_participation  sat_20_g12_participation  sat_20_g11_Participation  \
# 3               0.350073                  0.364629                  0.303623
# 7               0.047414                  0.303448                  0.023636
# 12              0.084108                  0.778810                  0.069577
# 15              0.069264                  0.666667                  0.010789
# 18              0.102763                  0.233640                  0.753885
#
#                             district  score  education_spend_per_student  \
# ...

# %%
plt.figure(figsize=(15 , 10))

correlation = combined.corr()

mask = np.zeros_like(correlation)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(correlation, annot=True, mask=mask, cmap="mako")

plt.title("If you do well on one, you are likely to do well on the other");

# %%
plt.figure(figsize=(15 , 10))

correlation = sat_and_act_total.corr()

mask = np.zeros_like(correlation)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(correlation, annot=True, mask=mask, cmap="mako")

plt.title("If you do well on one, you are likely to do well on the other");

# %% [markdown]
# As to be expected, students who score highly on the SAT do well on the SAT too.

# %% [markdown]
# # Visualize distributions using histograms

# %%
plt.figure(figsize=(12, 5))

plt.hist(sat_20_ca['sat_20_grade_12_at_both_benchmarks'], bins = 10)

plt.xlabel("Percentage of Students Over the Benchmark") # color is an optional argument in the above too
plt.ylabel("Total Districts")

plt.title("Distribution of Grade 12 Students Who Hit both SAT Benchmarks in 2020");

# %%
plt.figure(figsize=(12, 5))

plt.hist(act_20_ca['act_comp_over_21_20'], bins = 10)

plt.xlabel("Percentage of Students Over the Benchmark") # color is an optional argument in the above too
plt.ylabel("Total Districts")

plt.title("Distribution of Students Who Got an ACT Composite Score of at Least 21 in 2020");

# %% [markdown]
# If only about 50% of students are hitting benchmarks and the majority are from wealthier families how can standardized tests been seen as equitable?

# %% [markdown]
# # Plot and interpret boxplots

# %%
sns.boxplot(act_20_ca.act_20_participation, color = 'skyblue').set(xlabel='', title='ACT 2020 PARTICIPATION RATES');
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# It appears that even before the University of California put standardized testing on hold, ACT participation rates were down quite a bit.

# %%
sns.boxplot(act_19_ca.act_19_participation, color = 'yellow').set(xlabel='', title='ACT 2019 PARTICIPATION RATES');
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Outliers happening at the 40% mark seems worrying if tests like these are supposed to help students get into schools.
#
# Why are so many people just not bothering with writing them?

# %%
sns.boxplot(sat_19_ca.sat_19_g12_participation, color = 'skyblue').set(xlabel='', title='SAT 2019 GRADE 12 PARTICIPATION RATES');
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Even the more popular SAT sees ouliter participation rate at around 50%, and this was before the pandemic.

# %%
sns.boxplot(sat_20_ca.sat_20_g12_participation, color = 'yellow').set(xlabel='', title='SAT 2020 GRADE 12 PARTICIPATION RATES');
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
plt.scatter(x = act_20_ca['act_20_participation'],y = act_20_ca['avg_household_income'], c ='lightblue')
plt.title("ACT Partiticpation Rates and Household Income")
plt.xlabel('ACT 2020 Partiticpation Rates')
plt.ylabel('Average Household Income')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.scatter(x = sat_20_ca['sat_20_g12_participation'],y = sat_20_ca['avg_household_income'], c ='lightblue')
plt.title("Participation Rates and Household Income")
plt.xlabel('2020 Grade 12 SAT Partiticpation Rates')
plt.ylabel('Average Household Income')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.scatter(x = act_20_ca['act_comp_over_21_20'],y = act_20_ca['avg_household_income'], c ='lightblue')
plt.title("Students Who Do Well on the ACT Come From Wealthier Families")
plt.xlabel('Percentage of Students with Composite Scores Over 21 in 2020')
plt.ylabel('Average Household Income')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.scatter(x = sat_20_ca['sat_20_grade_12_at_both_benchmarks'],y = sat_20_ca['avg_household_income'], c ='lightblue')
plt.title("And It’s No Surprise That Household Income Plays a Role in the SAT Too")
plt.xlabel('Percentage of Grade 12 Students Who Hit Both Sat Benchmarks')
plt.ylabel('Average Household Income')
plt.show()

# %% [markdown]
# The scatter plots confirm what the tables earlier showed, there's a very strong correlation between wealth and academic succession.
#
# The relationship is simply too strong to ignore.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# While standardised tests in and of themselves are unbiased, their scores strongly favour students from richer backgrounds.
#
# While its beyond the scope of my analysis to conclude why that is, the why is not necessary when the evidence is as strong.
#
# If your house is on fire, you don't stop to figure out why. You deal with the problem first and address the why in the post mortem.
#
# While I spent my time looking at data which is essentially a series of numbers and strings, the fact is those numbers and strings represent actual people. People with dreams, hopes and ambitions. People, who these numbers and strings show always get the short end of the stick.
#
# That said, the University of California should permanently do away with standardised testing. And instead of using resources to develop their own testing as has been mentioned, the history of standardised testing shows that is repeatedly fails the same demographics - the marginalized and economically disadvantaged.
#
# Instead of putting more resources into that, the University of California should put time and effort into addressing the university they currently are, and the university they strive to become.
#
# The largest ethnic group in the state of California is hispanic.
#
# The university of California enrolls over 280,000 students across all of their campuses, 22% of which identify as hispanic, even though they make up 39% of the state's population.
#
# Similarly, under represented minorities are further under represented, as they only make 26% of the student of the student population, but make up 45% of the state's population.
#
# It's time to try something else.
